# %%
from recommendation import apriori, association_rules

# %%
import pandas as pd
import numpy as np

# %%
frequent_items = pd.read_csv('api/recommendation_objects/frequent_items.csv')

# %%
my_basket_sets = pd.read_csv('api/recommendation_objects/my_basket_sets.csv')

# %%
frequent_items1 = apriori(my_basket_sets, min_support = 0.05,use_colnames = True)
frequent_items1.head(50)
# Out:
#      support                                   itemsets
# 0   0.388889                               (Cappuccino)
# 1   0.382086                                    (Latte)
# 2   0.277022                           (Dark chocolate)
# 3   0.209373                            (Espresso shot)
# 4   0.200302                 (Sugar Free Vanilla syrup)
# 5   0.191232                             (Carmel syrup)
# 6   0.188964                          (Chocolate syrup)
# 7   0.171580                           (Hazelnut syrup)
# 8   0.135676                      (Chocolate Croissant)
# 9   0.133409                             (Ginger Scone)
# 10  0.116024                          (Cranberry Scone)
# 11  0.115646                         (Almond Croissant)
# 12  0.114890                       (Jumbo Savory Scone)
# 13  0.114135                                (Croissant)
# 14  0.113001     (Sugar Free Vanilla syrup, Cappuccino)
# 15  0.112623                  (Chocolate Chip Biscotti)
# ...

# %%
frequent_items1.head(50)
# Out:
#      support                                   itemsets
# 0   0.388889                               (Cappuccino)
# 1   0.382086                                    (Latte)
# 2   0.277022                           (Dark chocolate)
# 3   0.209373                            (Espresso shot)
# 4   0.200302                 (Sugar Free Vanilla syrup)
# 5   0.191232                             (Carmel syrup)
# 6   0.188964                          (Chocolate syrup)
# 7   0.171580                           (Hazelnut syrup)
# 8   0.135676                      (Chocolate Croissant)
# 9   0.133409                             (Ginger Scone)
# 10  0.116024                          (Cranberry Scone)
# 11  0.115646                         (Almond Croissant)
# 12  0.114890                       (Jumbo Savory Scone)
# 13  0.114135                                (Croissant)
# 14  0.113001     (Sugar Free Vanilla syrup, Cappuccino)
# 15  0.112623                  (Chocolate Chip Biscotti)
# ...

# %%
rules_basket = association_rules(frequent_items1, metric = "lift", min_threshold = 1)
rules_basket.head()
# Out:
#                   antecedents                 consequents  antecedent support  \
# 0  (Sugar Free Vanilla syrup)                (Cappuccino)            0.200302
# 1                (Cappuccino)  (Sugar Free Vanilla syrup)            0.388889
# 2           (Chocolate syrup)                (Cappuccino)            0.188964
# 3                (Cappuccino)           (Chocolate syrup)            0.388889
# 4                     (Latte)  (Sugar Free Vanilla syrup)            0.382086
#
#    consequent support   support  confidence      lift  leverage  conviction  \
# 0            0.388889  0.113001    0.564151  1.450674  0.035105    1.402116
# 1            0.200302  0.113001    0.290573  1.450674  0.035105    1.127245
# 2            0.388889  0.109599    0.580000  1.491429  0.036113    1.455026
# 3            0.188964  0.109599    0.281827  1.491429  0.036113    1.129304
# 4            0.200302  0.108844    0.284866  1.422182  0.032311    1.118249
#
#    zhangs_metric
# 0       0.286792
# ...

# %%
rules_basket[rules_basket['antecedents']=={'Latte'}].sort_values('confidence',ascending=False).head(50)
# Out:
#    antecedents                 consequents  antecedent support  \
# 4      (Latte)  (Sugar Free Vanilla syrup)            0.382086
# 6      (Latte)              (Carmel syrup)            0.382086
# 8      (Latte)           (Chocolate syrup)            0.382086
# 12     (Latte)            (Hazelnut syrup)            0.382086
# 32     (Latte)                 (Croissant)            0.382086
# 46     (Latte)              (Ginger Scone)            0.382086
# 48     (Latte)       (Chocolate Croissant)            0.382086
# 52     (Latte)          (Almond Croissant)            0.382086
# 54     (Latte)           (Ginger Biscotti)            0.382086
# 68     (Latte)           (Cranberry Scone)            0.382086
#
#     consequent support   support  confidence      lift  leverage  conviction  \
# 4             0.200302  0.108844    0.284866  1.422182  0.032311    1.118249
# 6             0.191232  0.107710    0.281899  1.474121  0.034643    1.126260
# ...
